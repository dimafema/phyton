# %%
class Autor: # clase Autor
    def __init__(self,nombre, apellidos): # Compuesta por dos atributos "Nombre, Apellidos"
        self.Nombre = nombre 
        self.Aplellidos = apellidos
    def MostrarAutor(self): # Creamos el método que muestra por pantalla los atributos "Nombre, Apellidos"
        prin("Autor: ",self.Nombre,"",self.Aplellidos)

class Libro: # clase Libro
    def __init__(self,titulo,isbn): # se componen de dos atributos "Titulo, ISNB"
        self.Titulo = titulo
        self.ISBN = isbn
    def AñadirAutor(self,autor): # método que añade el atributo "Autor" que almacena la información en la clase Autor
        self.Autor = Autor
    def MostrarLibro(self): # método que muestra el libro y el autor
        print("------Libro------")
        print("Título: ",self.Titulo)
        print("ISBN: ",self.ISBN)
        self.Autor.MostrarAutor()
        print("----------------")
    def ObtenerTitulo(self): # método devuelve el título del libro
        return self.Titulo;

class Biblioteca:
    def __init__(self): # Con un atributo "listaLibros"
        self.ListaLibros = []
    def NumeroLibros(self):
        return len(self.ListaLibros)
    def AñadirLibro(self,Libros)
        self.ListarLibros = self.ListaLibros + [libro]
    def MostrarBiblioteca(self):
        print("###############################")
        for item in self.ListaLibros:
            item.MostrarLibro()
        print("###############################")
    def BorrarLibro(self,titulo):
        encontrardo = False
        posicionaBorrar = -1
        for item in self.ListarLibros:
            posicionaBorrar += 1
            if item.ObtenerTitulo() == titulo:
                encontrardo = True
                break
        if encontrardo:
            del self.ListarLibros[posicionaBorrar]
                print("¡Libro borrado correctamente!")
            else:
                print("¡Libro no encontrado")
    def MostrarMenu():
        print("""Menu
        1) Añadir libro a la biblioteca
        2) Mostrar biblioteca
        3) Borrar libro
        4) ¿Número de libros?
        5) Salir""")
